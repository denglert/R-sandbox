# %% [markdown]
# # This notebook runs in R
#
# The R environment
# R is an integrated suite of software facilities for data manipulation, calculation and graphical display. Among other things it has
# • an e ective data handling and storage facility,
# • a suite of operators for calculations on arrays, in particular matrices,
# • a large, coherent, integrated collection of intermediate tools for data analysis,
# • graphical facilities for data analysis and display either directly at the computer or on hard- copy, and
# • a well developed, simple and e ective programming language (called ‘S’) which includes conditionals, loops, user de ned recursive functions and input and output facilities. (Indeed most of the system supplied functions are themselves written in the S language.)

# %% [markdown]
# ### Most importantly:
#
# Getting help and looking up the documentation: for example the command "solve" one can use

# %%
help(solve)

# %% [markdown]
# or the command

# %%
?solve

# %% [markdown]
# This opens a documentation window, where the command, its inputs and its use is explained.

# %% [markdown]
# ### Simple vectors and operations
#
#
# As opposed to Python, one assigns values  to a variable by using an arrow

# %%
w<-1
2->w2
c(w,w2)
# Out:
# [1] 1 2

# %%
x<-c(1:5)
x
# Out:
# [1] 1 2 3 4 5

# %%
c+4
# Out:
# [1] 7

# %%
y<-c(1.5,2.5,3.5,4.5,5.5)

# %% [markdown]
# Basic operations

# %%
v<-2*x+y+1
v
# Out:
# [1]  4.5  7.5 10.5 13.5 16.5

# %% [markdown]
# All of the arithmetic operations are available without loading: sqrt, exp, log, sin, cos, tan

# %%
sqrt(x)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected ','
# 1: sqrt(x),
#            ^
# Traceback:

# %%
exp(y)
# Out:
# [1]   4.481689  12.182494  33.115452  90.017131 244.691932

# %% [markdown]
# One can easily select the smallest and largest elements of a tuple and here or compute the mean or the length of an input:

# %%
min(x)
# Out:
# [1] 1

# %%
max(x)
# Out:
# [1] 5

# %%
mean(y)
# Out:
# [1] 3.5

# %%
length(w)
# Out:
# [1] 1

# %%
length(x)
# Out:
# [1] 5

# %% [markdown]
# ### The class of an object
# All objects in R have a class, reported by the function class. For simple vectors this is just the mode, for example "numeric", "logical", "character" or "list", but "matrix", "array", "factor" and "data.frame" are other possible values.

# %% [markdown]
# ### Plotting

# %%
plot(x)
# Out:
# plot without title
